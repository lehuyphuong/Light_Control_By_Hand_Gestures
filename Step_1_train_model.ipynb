# %% [markdown]
# <a href="https://colab.research.google.com/github/lehuyphuong/Light_Control_By_Hand_Gestures/blob/feature%2Fstep_1_train_model/Step_1_train_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mediapipe==0.10.18
# Out:
# Collecting mediapipe==0.10.18
#   Downloading mediapipe-0.10.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (24.3.25)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.4.33)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.4.33)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (3.8.0)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (4.25.5)
# Collecting sounddevice>=0.4.4 (from mediapipe==0.10.18)
#   Downloading sounddevice-0.5.1-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe==0.10.18) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe==0.10.18) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe==0.10.18) (1.16.0)
# Downloading mediapipe-0.10.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.1/36.1 MB 32.0 MB/s eta 0:00:00
# Downloading sounddevice-0.5.1-py3-none-any.whl (32 kB)
# Installing collected packages: sounddevice, mediapipe
# Successfully installed mediapipe-0.10.18 sounddevice-0.5.1

# %%
# !pip install torchmetrics
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.6.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (24.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.5.1+cu121)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.2)
# Downloading torchmetrics-1.6.0-py3-none-any.whl (926 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 926.4/926.4 kB 12.5 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Installing collected packages: lightning-utilities, torchmetrics
# Successfully installed lightning-utilities-0.11.9 torchmetrics-1.6.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchmetrics import Accuracy
from torch.utils.data import Dataset, DataLoader
import yaml
import torch.optim as optim
import cv2
import mediapipe as mp
import datetime as datetime
import os

# %%
def label_dict_from_config_file(relative_path):
    with open(relative_path,"r") as f:
       label_tag = yaml.full_load(f)["gestures"]
    return label_tag

# %%
class NeuralNetwork(nn.Module):
  def __init__(self):
    super(NeuralNetwork, self).__init__()
    self.flatten = nn.Flatten()
    list_label = label_dict_from_config_file("/content/drive/MyDrive/AIO_2024/Module_5/Week_5/hand_gesture.yaml")
    self.linear_relu_stack = nn.Sequential(
        nn.Linear(63, 128),
        nn.ReLU(),
        nn.BatchNorm1d(128),
        nn.Linear(128, 128),
        nn.ReLU(),
        nn.Dropout(p=0.4),
        nn.Linear(128, 128),
        nn.ReLU(),
        nn.Dropout(p=0.4),
        nn.Linear(128, 128),
        nn.ReLU(),
        nn.Dropout(p=0.6),
        nn.Linear(128, len(list_label))
    )

  def forward(self, x):
    x = self.flatten(x)
    x = self.linear_relu_stack(x)
    return x

  def predict(self, x, threshold=0.8):
    logits = self(x)
    softmax_prob = nn.Softmax(dim=1)(logits)
    chosen_ind = torch.argmax(softmax_prob, dim=1)
    return torch.where(softmax_prob[0, chosen_ind] > threshold, chosen_ind, -1)

  def predict_with_known_class(self, x):
    logits = self(x)
    softmax_prob = nn.Softmax(dim=1)(logits)
    return torch.argmax(softmax_prob, dim=1)

  def score(self, logits):
    return -torch.amax(logits, dim=1)

# %%
class HandLandmarksDetector():
    def __init__(self) -> None:
        self.mp_drawing = mp.solutions.drawing_utils
        self.mp_drawing_styles = mp.solutions.drawing_styles
        self.mp_hands = mp.solutions.hands
        self.detector = self.mp_hands.Hands(
            False, max_num_hands=1, min_detection_confidence=0.5)

    def detectHand(self, frame):
        hands = []
        frame = cv2.flip(frame, 1)
        annotated_image = frame.copy()
        results = self.detector.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

        if results.multi_hand_landmarks is not None:
            for hand_landmarks in results.multi_hand_landmarks:
                hand = []
                self.mp_drawing.draw_landmarks(
                    annotated_image,
                    hand_landmarks,
                    self.mp_hands.HAND_CONNECTIONS,
                    self.mp_drawing_styles.get_default_hand_landmarks_style(),
                    self.mp_drawing_styles.get_default_hand_connections_style()
                )

                for landmark in hand_landmarks.landmark:
                    x, y, z = landmark.x, landmark.y, landmark.z
                    hand.extend([x, y, z])

            hands.append(hand)

        return hands, annotated_image

# %%
class CustomImageDataset(Dataset):
  def __init__(self, data_file):
    self.data = pd.read_csv(data_file)
    self.labels = torch.from_numpy(self.data.iloc[:, 0].to_numpy())

  def __len__(self):
    return len(self.data)

  def __getitem__(self, idx):
    one_hot_label = self.labels[idx]
    torch_data = torch.from_numpy(self.data.iloc[idx, 1:].to_numpy(dtype=np.float32))
    return torch_data, one_hot_label

# %%
class EarlyStopper:
  def __init__(self, patience=1, min_delta=0):
    self.patience = patience
    self.min_delta = min_delta
    self.counter = 0
    self.watched_metrics = np.inf

  def early_stop(self, current_value):
    if current_value < self.watched_metrics:
      self.watched_metrics = current_value
      self.counter = 0
    elif current_value > (self.watched_metrics + self.min_delta):
      self.counter += 1
      if self.counter >= self.patience:
        return True

    return False

# %%
def train(trainloader, val_loader, model, loss_function, early_stopper, optimizer):
  best_vloss = 1_000_000
  # timestamp = datetime.now().strftime('%d-%m %H:%M')

  for epoch in range(300):
    # training
    model.train(True)
    running_loss = 0.0
    acc_train = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
    for batch_number, data in enumerate(trainloader):
      inputs, labels = data

      # reset gradient
      optimizer.zero_grad()

      # predict class bases on given inputs
      preds = model(inputs)

      # calculate loss, perform backward and update parameters
      loss = loss_function(preds, labels)
      loss.backward()
      optimizer.step()

      acc_train.update(model.predict_with_known_class(inputs), labels)
      running_loss += loss.item()

    avg_loss = running_loss / len(trainloader)

    # validating step
    model.train(False)
    running_vloss = 0.0
    acc_val = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')

    for i, vdata in enumerate(val_loader):
      vinputs, vlabels = vdata
      preds = model(vinputs)
      vloss = loss_function(preds, vlabels)
      running_vloss + vloss.item()
      acc_val.update(model.predict_with_known_class(vinputs), vlabels)


    # log the running loss averaged per batch
    print(f"Epoch {epoch}: ")
    print(f"Accuracy train: {acc_train.compute().item()}, val:{acc_val.compute().item()}")

    avg_vloss = running_vloss / len(val_loader)
    print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))
    print('Training vs Validation loss',
          {'Training' : avg_loss, 'Validation' : avg_loss}, epoch + 1)

    print('Training vs validation loss',
          {'Training' : acc_train.compute().item(),
           'Validation' : acc_val.compute().item()}, epoch + 1)

    # track performance
    if avg_vloss < best_vloss:
      best_vloss = avg_vloss
      best_model_path = f'{save_path}/model_{model.__class__.__name__}_best'
      torch.save(model.state_dict(), best_model_path)

    if early_stopper.early_stop(avg_loss):
      print ( f" stopping at epoch { epoch } , minimum : { early_stopper . watched_metrics }")
      break

  model_path = f'{save_path}/model_{model.__class__.__name__}_last'
  torch.save(model.state_dict(), model_path)
  print(acc_val.compute())
  return model, best_model_path

# %%
DATA_FOLDER_PATH="/content/drive/MyDrive/AIO_2024/Module_5/Week_5/data"
LIST_LABEL = label_dict_from_config_file("/content/drive/MyDrive/AIO_2024/Module_5/Week_5/hand_gesture.yaml")
train_path = os.path.join(DATA_FOLDER_PATH,"landmark_train.csv")
val_path = os.path.join(DATA_FOLDER_PATH,"landmark_val.csv")
save_path = '/content/drive/MyDrive/AIO_2024/Module_5/Week_5/models'
os.makedirs(save_path,exist_ok=True)
trainset = CustomImageDataset(train_path)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=40, shuffle=True)

valset = CustomImageDataset(os.path.join(val_path))
val_loader = torch.utils.data.DataLoader(valset, batch_size=50, shuffle=False)

model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience=30, min_delta=0.01)

optimizer = optim.Adam(model.parameters(), lr=0.0001)

model, best_model_path = train(trainloader, val_loader, model, loss_function, early_stopper, optimizer)
# Out:
# Epoch 0:
# Accuracy train: 0.6592458486557007, val:0.9913240075111389
# LOSS train 1.047553009967335 valid 0.0
# Training vs Validation loss {'Training': 1.047553009967335, 'Validation': 1.047553009967335} 1
# Training vs validation loss {'Training': 0.6592458486557007, 'Validation': 0.9913240075111389} 1
# Epoch 1:
# Accuracy train: 0.9894027709960938, val:0.9922670722007751
# LOSS train 0.09647761847934548 valid 0.0
# Training vs Validation loss {'Training': 0.09647761847934548, 'Validation': 0.09647761847934548} 2
# Training vs validation loss {'Training': 0.9894027709960938, 'Validation': 0.9922670722007751} 2
# Epoch 2:
# Accuracy train: 0.9917029738426208, val:0.9924556612968445
# LOSS train 0.04698825086940263 valid 0.0
# Training vs Validation loss {'Training': 0.04698825086940263, 'Validation': 0.04698825086940263} 3
# Training vs validation loss {'Training': 0.9917029738426208, 'Validation': 0.9924556612968445} 3
# Epoch 3:
# Accuracy train: 0.9921137094497681, val:0.9920784831047058
# LOSS train 0.04020264175048739 valid 0.0
# Training vs Validation loss {'Training': 0.04020264175048739, 'Validation': 0.04020264175048739} 4
# Training vs validation loss {'Training': 0.9921137094497681, 'Validation': 0.9920784831047058} 4
# Epoch 4:
# Accuracy train: 0.9921958446502686, val:0.9926443099975586
# LOSS train 0.03480543120035169 valid 0.0
# Training vs Validation loss {'Training': 0.03480543120035169, 'Validation': 0.03480543120035169} 5
# Training vs validation loss {'Training': 0.9921958446502686, 'Validation': 0.9926443099975586} 5
# Epoch 5:
# Accuracy train: 0.9926887154579163, val:0.9911354184150696
# LOSS train 0.03176786567954743 valid 0.0
# Training vs Validation loss {'Training': 0.03176786567954743, 'Validation': 0.03176786567954743} 6
# Training vs validation loss {'Training': 0.9926887154579163, 'Validation': 0.9911354184150696} 6
# Epoch 6:
# Accuracy train: 0.992277979850769, val:0.994907557964325
# LOSS train 0.028580497612520198 valid 0.0
# Training vs Validation loss {'Training': 0.028580497612520198, 'Validation': 0.028580497612520198} 7
# Training vs validation loss {'Training': 0.992277979850769, 'Validation': 0.994907557964325} 7
# Epoch 7:
# Accuracy train: 0.9919493794441223, val:0.9960392117500305
# LOSS train 0.027299712230756758 valid 0.0
# Training vs Validation loss {'Training': 0.027299712230756758, 'Validation': 0.027299712230756758} 8
# Training vs validation loss {'Training': 0.9919493794441223, 'Validation': 0.9960392117500305} 8
# Epoch 8:
# Accuracy train: 0.9926065802574158, val:0.9954733848571777
# LOSS train 0.02438997893353741 valid 0.0
# Training vs Validation loss {'Training': 0.02438997893353741, 'Validation': 0.02438997893353741} 9
# Training vs validation loss {'Training': 0.9926065802574158, 'Validation': 0.9954733848571777} 9
# Epoch 9:
# Accuracy train: 0.9925244450569153, val:0.9920784831047058
# LOSS train 0.02388094283325968 valid 0.0
# Training vs Validation loss {'Training': 0.02388094283325968, 'Validation': 0.02388094283325968} 10
# Training vs validation loss {'Training': 0.9925244450569153, 'Validation': 0.9920784831047058} 10
# Epoch 10:
# Accuracy train: 0.992853045463562, val:0.9977366924285889
# LOSS train 0.020289088435829845 valid 0.0
# Training vs Validation loss {'Training': 0.020289088435829845, 'Validation': 0.020289088435829845} 11
# Training vs validation loss {'Training': 0.992853045463562, 'Validation': 0.9977366924285889} 11
# Epoch 11:
# Accuracy train: 0.9932637810707092, val:0.9845341444015503
# LOSS train 0.020690594680932234 valid 0.0
# Training vs Validation loss {'Training': 0.020690594680932234, 'Validation': 0.020690594680932234} 12
# Training vs validation loss {'Training': 0.9932637810707092, 'Validation': 0.9845341444015503} 12
# Epoch 12:
# Accuracy train: 0.9934280514717102, val:0.996416449546814
# LOSS train 0.018365090011908163 valid 0.0
# Training vs Validation loss {'Training': 0.018365090011908163, 'Validation': 0.018365090011908163} 13
# Training vs validation loss {'Training': 0.9934280514717102, 'Validation': 0.996416449546814} 13
# Epoch 13:
# Accuracy train: 0.9930995106697083, val:0.994907557964325
# LOSS train 0.01636115541659223 valid 0.0
# Training vs Validation loss {'Training': 0.01636115541659223, 'Validation': 0.01636115541659223} 14
# Training vs validation loss {'Training': 0.9930995106697083, 'Validation': 0.994907557964325} 14
# Epoch 14:
# Accuracy train: 0.9935102462768555, val:0.9835910797119141
# LOSS train 0.01887221197576749 valid 0.0
# Training vs Validation loss {'Training': 0.01887221197576749, 'Validation': 0.01887221197576749} 15
# Training vs validation loss {'Training': 0.9935102462768555, 'Validation': 0.9835910797119141} 15
# Epoch 15:
# Accuracy train: 0.9936745166778564, val:0.9849113821983337
# LOSS train 0.014388300513049023 valid 0.0
# Training vs Validation loss {'Training': 0.014388300513049023, 'Validation': 0.014388300513049023} 16
# Training vs validation loss {'Training': 0.9936745166778564, 'Validation': 0.9849113821983337} 16
# Epoch 16:
# Accuracy train: 0.993592381477356, val:0.9824594259262085
# LOSS train 0.013405200528442768 valid 0.0
# Training vs Validation loss {'Training': 0.013405200528442768, 'Validation': 0.013405200528442768} 17
# Training vs validation loss {'Training': 0.993592381477356, 'Validation': 0.9824594259262085} 17
# Epoch 17:
# Accuracy train: 0.9942495822906494, val:0.9960392117500305
# LOSS train 0.013808391893370917 valid 0.0
# Training vs Validation loss {'Training': 0.013808391893370917, 'Validation': 0.013808391893370917} 18
# Training vs validation loss {'Training': 0.9942495822906494, 'Validation': 0.9960392117500305} 18
# Epoch 18:
# Accuracy train: 0.9941674470901489, val:0.9892493486404419
# LOSS train 0.013454696856552189 valid 0.0
# Training vs Validation loss {'Training': 0.013454696856552189, 'Validation': 0.013454696856552189} 19
# Training vs validation loss {'Training': 0.9941674470901489, 'Validation': 0.9892493486404419} 19
# Epoch 19:
# Accuracy train: 0.9950710535049438, val:0.9849113821983337
# LOSS train 0.013873478517975631 valid 0.0
# Training vs Validation loss {'Training': 0.013873478517975631, 'Validation': 0.013873478517975631} 20
# Training vs validation loss {'Training': 0.9950710535049438, 'Validation': 0.9849113821983337} 20
# Epoch 20:
# Accuracy train: 0.9955639243125916, val:0.9896265268325806
# LOSS train 0.013553959357427705 valid 0.0
# Training vs Validation loss {'Training': 0.013553959357427705, 'Validation': 0.013553959357427705} 21
# Training vs validation loss {'Training': 0.9955639243125916, 'Validation': 0.9896265268325806} 21
# Epoch 21:
# Accuracy train: 0.9951531887054443, val:0.9775556325912476
# LOSS train 0.011396965256936396 valid 0.0
# Training vs Validation loss {'Training': 0.011396965256936396, 'Validation': 0.011396965256936396} 22
# Training vs validation loss {'Training': 0.9951531887054443, 'Validation': 0.9775556325912476} 22
# Epoch 22:
# Accuracy train: 0.9958925247192383, val:0.9875518679618835
# LOSS train 0.011369876939836819 valid 0.0
# Training vs Validation loss {'Training': 0.011369876939836819, 'Validation': 0.011369876939836819} 23
# Training vs validation loss {'Training': 0.9958925247192383, 'Validation': 0.9875518679618835} 23
# Epoch 23:
# Accuracy train: 0.9950710535049438, val:0.9856657981872559
# LOSS train 0.012016804144997102 valid 0.0
# Training vs Validation loss {'Training': 0.012016804144997102, 'Validation': 0.012016804144997102} 24
# Training vs validation loss {'Training': 0.9950710535049438, 'Validation': 0.9856657981872559} 24
# Epoch 24:
# Accuracy train: 0.9954817891120911, val:0.9717087745666504
# LOSS train 0.010769781160881215 valid 0.0
# Training vs Validation loss {'Training': 0.010769781160881215, 'Validation': 0.010769781160881215} 25
# Training vs validation loss {'Training': 0.9954817891120911, 'Validation': 0.9717087745666504} 25
# Epoch 25:
# Accuracy train: 0.9966318607330322, val:0.9837797284126282
# LOSS train 0.009787599569592546 valid 0.0
# Training vs Validation loss {'Training': 0.009787599569592546, 'Validation': 0.009787599569592546} 26
# Training vs validation loss {'Training': 0.9966318607330322, 'Validation': 0.9837797284126282} 26
# Epoch 26:
# Accuracy train: 0.996221125125885, val:0.9952847957611084
# LOSS train 0.00927816573690939 valid 0.0
# Training vs Validation loss {'Training': 0.00927816573690939, 'Validation': 0.00927816573690939} 27
# Training vs validation loss {'Training': 0.996221125125885, 'Validation': 0.9952847957611084} 27
# Epoch 27:
# Accuracy train: 0.9958925247192383, val:0.9817050099372864
# LOSS train 0.009888033756324969 valid 0.0
# Training vs Validation loss {'Training': 0.009888033756324969, 'Validation': 0.009888033756324969} 28
# Training vs validation loss {'Training': 0.9958925247192383, 'Validation': 0.9817050099372864} 28
# Epoch 28:
# Accuracy train: 0.9970426559448242, val:0.9867974519729614
# LOSS train 0.009075378021003179 valid 0.0
# Training vs Validation loss {'Training': 0.009075378021003179, 'Validation': 0.009075378021003179} 29
# Training vs validation loss {'Training': 0.9970426559448242, 'Validation': 0.9867974519729614} 29
# Epoch 29:
# Accuracy train: 0.9974533915519714, val:0.9890607595443726
# LOSS train 0.008647874875113615 valid 0.0
# Training vs Validation loss {'Training': 0.008647874875113615, 'Validation': 0.008647874875113615} 30
# Training vs validation loss {'Training': 0.9974533915519714, 'Validation': 0.9890607595443726} 30
# Epoch 30:
# Accuracy train: 0.9967140555381775, val:0.9852885603904724
# LOSS train 0.010609108362070371 valid 0.0
# Training vs Validation loss {'Training': 0.010609108362070371, 'Validation': 0.010609108362070371} 31
# Training vs validation loss {'Training': 0.9967140555381775, 'Validation': 0.9852885603904724} 31
# Epoch 31:
# Accuracy train: 0.996960461139679, val:0.9835910797119141
# LOSS train 0.007550963793058697 valid 0.0
# Training vs Validation loss {'Training': 0.007550963793058697, 'Validation': 0.007550963793058697} 32
# Training vs validation loss {'Training': 0.996960461139679, 'Validation': 0.9835910797119141} 32
# Epoch 32:
# Accuracy train: 0.997371256351471, val:0.9737834930419922
# LOSS train 0.007529445204500752 valid 0.0
# Training vs Validation loss {'Training': 0.007529445204500752, 'Validation': 0.007529445204500752} 33
# Training vs validation loss {'Training': 0.997371256351471, 'Validation': 0.9737834930419922} 33
# Epoch 33:
# Accuracy train: 0.9976176619529724, val:0.9760468006134033
# LOSS train 0.00850144308972437 valid 0.0
# Training vs Validation loss {'Training': 0.00850144308972437, 'Validation': 0.00850144308972437} 34
# Training vs validation loss {'Training': 0.9976176619529724, 'Validation': 0.9760468006134033} 34
# Epoch 34:
# Accuracy train: 0.9977819919586182, val:0.9883062839508057
# LOSS train 0.00682298403994835 valid 0.0
# Training vs Validation loss {'Training': 0.00682298403994835, 'Validation': 0.00682298403994835} 35
# Training vs validation loss {'Training': 0.9977819919586182, 'Validation': 0.9883062839508057} 35
# Epoch 35:
# Accuracy train: 0.9970426559448242, val:0.9881176948547363
# LOSS train 0.008540992546496737 valid 0.0
# Training vs Validation loss {'Training': 0.008540992546496737, 'Validation': 0.008540992546496737} 36
# Training vs validation loss {'Training': 0.9970426559448242, 'Validation': 0.9881176948547363} 36
# Epoch 36:
# Accuracy train: 0.996796190738678, val:0.9862316250801086
# LOSS train 0.007181730762630889 valid 0.0
# Training vs Validation loss {'Training': 0.007181730762630889, 'Validation': 0.007181730762630889} 37
# Training vs validation loss {'Training': 0.996796190738678, 'Validation': 0.9862316250801086} 37
# Epoch 37:
# Accuracy train: 0.9980283975601196, val:0.9675593972206116
# LOSS train 0.006152800783009104 valid 0.0
# Training vs Validation loss {'Training': 0.006152800783009104, 'Validation': 0.006152800783009104} 38
# Training vs validation loss {'Training': 0.9980283975601196, 'Validation': 0.9675593972206116} 38
# Epoch 38:
# Accuracy train: 0.9974533915519714, val:0.9877404570579529
# LOSS train 0.007887364353705678 valid 0.0
# Training vs Validation loss {'Training': 0.007887364353705678, 'Validation': 0.007887364353705678} 39
# Training vs validation loss {'Training': 0.9974533915519714, 'Validation': 0.9877404570579529} 39
# Epoch 39:
# Accuracy train: 0.9971247911453247, val:0.9837797284126282
# LOSS train 0.008431348347235666 valid 0.0
# Training vs Validation loss {'Training': 0.008431348347235666, 'Validation': 0.008431348347235666} 40
# Training vs validation loss {'Training': 0.9971247911453247, 'Validation': 0.9837797284126282} 40
# Epoch 40:
# Accuracy train: 0.9976176619529724, val:0.9656733274459839
# LOSS train 0.005890080473409398 valid 0.0
# Training vs Validation loss {'Training': 0.005890080473409398, 'Validation': 0.005890080473409398} 41
# Training vs validation loss {'Training': 0.9976176619529724, 'Validation': 0.9656733274459839} 41
# Epoch 41:
# Accuracy train: 0.997371256351471, val:0.9805733561515808
# LOSS train 0.0071770340952072775 valid 0.0
# Training vs Validation loss {'Training': 0.0071770340952072775, 'Validation': 0.0071770340952072775} 42
# Training vs validation loss {'Training': 0.997371256351471, 'Validation': 0.9805733561515808} 42
# Epoch 42:
# Accuracy train: 0.9983569979667664, val:0.9602037072181702
# LOSS train 0.005163216162128772 valid 0.0
# Training vs Validation loss {'Training': 0.005163216162128772, 'Validation': 0.005163216162128772} 43
# Training vs validation loss {'Training': 0.9983569979667664, 'Validation': 0.9602037072181702} 43
# Epoch 43:
# Accuracy train: 0.997371256351471, val:0.9718974232673645
# LOSS train 0.0066670746316087395 valid 0.0
# Training vs Validation loss {'Training': 0.0066670746316087395, 'Validation': 0.0066670746316087395} 44
# Training vs validation loss {'Training': 0.997371256351471, 'Validation': 0.9718974232673645} 44
# Epoch 44:
# Accuracy train: 0.9967140555381775, val:0.9930214881896973
# LOSS train 0.011017347877823555 valid 0.0
# Training vs Validation loss {'Training': 0.011017347877823555, 'Validation': 0.011017347877823555} 45
# Training vs validation loss {'Training': 0.9967140555381775, 'Validation': 0.9930214881896973} 45
# Epoch 45:
# Accuracy train: 0.9959747195243835, val:0.9967936873435974
# LOSS train 0.010007578846055323 valid 0.0
# Training vs Validation loss {'Training': 0.010007578846055323, 'Validation': 0.010007578846055323} 46
# Training vs validation loss {'Training': 0.9959747195243835, 'Validation': 0.9967936873435974} 46
# Epoch 46:
# Accuracy train: 0.9970426559448242, val:0.9928328990936279
# LOSS train 0.009705047177798867 valid 0.0
# Training vs Validation loss {'Training': 0.009705047177798867, 'Validation': 0.009705047177798867} 47
# Training vs validation loss {'Training': 0.9970426559448242, 'Validation': 0.9928328990936279} 47
# Epoch 47:
# Accuracy train: 0.9970426559448242, val:0.991512656211853
# LOSS train 0.007316281908091525 valid 0.0
# Training vs Validation loss {'Training': 0.007316281908091525, 'Validation': 0.007316281908091525} 48
# Training vs validation loss {'Training': 0.9970426559448242, 'Validation': 0.991512656211853} 48
# Epoch 48:
# Accuracy train: 0.9974533915519714, val:0.9892493486404419
# LOSS train 0.00703521513798865 valid 0.0
# Training vs Validation loss {'Training': 0.00703521513798865, 'Validation': 0.00703521513798865} 49
# Training vs validation loss {'Training': 0.9974533915519714, 'Validation': 0.9892493486404419} 49
# Epoch 49:
# Accuracy train: 0.9965497255325317, val:0.99358731508255
# LOSS train 0.009404711010328817 valid 0.0
# Training vs Validation loss {'Training': 0.009404711010328817, 'Validation': 0.009404711010328817} 50
# Training vs validation loss {'Training': 0.9965497255325317, 'Validation': 0.99358731508255} 50
# Epoch 50:
# Accuracy train: 0.996960461139679, val:0.9867974519729614
# LOSS train 0.00839268721659873 valid 0.0
# Training vs Validation loss {'Training': 0.00839268721659873, 'Validation': 0.00839268721659873} 51
# Training vs validation loss {'Training': 0.996960461139679, 'Validation': 0.9867974519729614} 51
# Epoch 51:
# Accuracy train: 0.9972890615463257, val:0.9917012453079224
# LOSS train 0.007451712744512138 valid 0.0
# Training vs Validation loss {'Training': 0.007451712744512138, 'Validation': 0.007451712744512138} 52
# Training vs validation loss {'Training': 0.9972890615463257, 'Validation': 0.9917012453079224} 52
# Epoch 52:
# Accuracy train: 0.9983569979667664, val:0.9917012453079224
# LOSS train 0.006330623334672435 valid 0.0
# Training vs Validation loss {'Training': 0.006330623334672435, 'Validation': 0.006330623334672435} 53
# Training vs validation loss {'Training': 0.9983569979667664, 'Validation': 0.9917012453079224} 53
# Epoch 53:
# Accuracy train: 0.9977819919586182, val:0.9883062839508057
# LOSS train 0.0064886402138197765 valid 0.0
# Training vs Validation loss {'Training': 0.0064886402138197765, 'Validation': 0.0064886402138197765} 54
# Training vs validation loss {'Training': 0.9977819919586182, 'Validation': 0.9883062839508057} 54
# Epoch 54:
# Accuracy train: 0.9975355267524719, val:0.9841569066047668
# LOSS train 0.008109067778651828 valid 0.0
# Training vs Validation loss {'Training': 0.008109067778651828, 'Validation': 0.008109067778651828} 55
# Training vs validation loss {'Training': 0.9975355267524719, 'Validation': 0.9841569066047668} 55
# Epoch 55:
# Accuracy train: 0.9968783259391785, val:0.9913240075111389
# LOSS train 0.007113630623987282 valid 0.0
# Training vs Validation loss {'Training': 0.007113630623987282, 'Validation': 0.007113630623987282} 56
# Training vs validation loss {'Training': 0.9968783259391785, 'Validation': 0.9913240075111389} 56
# Epoch 56:
# Accuracy train: 0.9978641271591187, val:0.9884949326515198
# LOSS train 0.006131842166931977 valid 0.0
# Training vs Validation loss {'Training': 0.006131842166931977, 'Validation': 0.006131842166931977} 57
# Training vs validation loss {'Training': 0.9978641271591187, 'Validation': 0.9884949326515198} 57
# Epoch 57:
# Accuracy train: 0.9974533915519714, val:0.9924556612968445
# LOSS train 0.0059324089283597356 valid 0.0
# Training vs Validation loss {'Training': 0.0059324089283597356, 'Validation': 0.0059324089283597356} 58
# Training vs validation loss {'Training': 0.9974533915519714, 'Validation': 0.9924556612968445} 58
# Epoch 58:
# Accuracy train: 0.996960461139679, val:0.9769898056983948
# LOSS train 0.009155435353249022 valid 0.0
# Training vs Validation loss {'Training': 0.009155435353249022, 'Validation': 0.009155435353249022} 59
# Training vs validation loss {'Training': 0.996960461139679, 'Validation': 0.9769898056983948} 59
# Epoch 59:
# Accuracy train: 0.9974533915519714, val:0.9788758754730225
# LOSS train 0.007307097287916357 valid 0.0
# Training vs Validation loss {'Training': 0.007307097287916357, 'Validation': 0.007307097287916357} 60
# Training vs validation loss {'Training': 0.9974533915519714, 'Validation': 0.9788758754730225} 60
# Epoch 60:
# Accuracy train: 0.9981927275657654, val:0.986420214176178
# LOSS train 0.007236837088171491 valid 0.0
# Training vs Validation loss {'Training': 0.007236837088171491, 'Validation': 0.007236837088171491} 61
# Training vs validation loss {'Training': 0.9981927275657654, 'Validation': 0.986420214176178} 61
# Epoch 61:
# Accuracy train: 0.9976176619529724, val:0.9930214881896973
# LOSS train 0.0064101397635771135 valid 0.0
# Training vs Validation loss {'Training': 0.0064101397635771135, 'Validation': 0.0064101397635771135} 62
# Training vs validation loss {'Training': 0.9976176619529724, 'Validation': 0.9930214881896973} 62
# Epoch 62:
# Accuracy train: 0.9976998567581177, val:0.9932101368904114
# LOSS train 0.008787470425128221 valid 0.0
# Training vs Validation loss {'Training': 0.008787470425128221, 'Validation': 0.008787470425128221} 63
# Training vs validation loss {'Training': 0.9976998567581177, 'Validation': 0.9932101368904114} 63
# Epoch 63:
# Accuracy train: 0.9980283975601196, val:0.9907581806182861
# LOSS train 0.005050676567409515 valid 0.0
# Training vs Validation loss {'Training': 0.005050676567409515, 'Validation': 0.005050676567409515} 64
# Training vs validation loss {'Training': 0.9980283975601196, 'Validation': 0.9907581806182861} 64
# Epoch 64:
# Accuracy train: 0.9980283975601196, val:0.987929105758667
# LOSS train 0.004575591848471945 valid 0.0
# Training vs Validation loss {'Training': 0.004575591848471945, 'Validation': 0.004575591848471945} 65
# Training vs validation loss {'Training': 0.9980283975601196, 'Validation': 0.987929105758667} 65
# Epoch 65:
# Accuracy train: 0.9983569979667664, val:0.9947189688682556
# LOSS train 0.00439813777589259 valid 0.0
# Training vs Validation loss {'Training': 0.00439813777589259, 'Validation': 0.00439813777589259} 66
# Training vs validation loss {'Training': 0.9983569979667664, 'Validation': 0.9947189688682556} 66
# Epoch 66:
# Accuracy train: 0.9975355267524719, val:0.9947189688682556
# LOSS train 0.005666831622780223 valid 0.0
# Training vs Validation loss {'Training': 0.005666831622780223, 'Validation': 0.005666831622780223} 67
# Training vs validation loss {'Training': 0.9975355267524719, 'Validation': 0.9947189688682556} 67
# Epoch 67:
# Accuracy train: 0.9981105923652649, val:0.984345555305481
# LOSS train 0.004805698876353543 valid 0.0
# Training vs Validation loss {'Training': 0.004805698876353543, 'Validation': 0.004805698876353543} 68
# Training vs validation loss {'Training': 0.9981105923652649, 'Validation': 0.984345555305481} 68
# Epoch 68:
# Accuracy train: 0.9975355267524719, val:0.9883062839508057
# LOSS train 0.006774872238103908 valid 0.0
# Training vs Validation loss {'Training': 0.006774872238103908, 'Validation': 0.006774872238103908} 69
# Training vs validation loss {'Training': 0.9975355267524719, 'Validation': 0.9883062839508057} 69
# Epoch 69:
# Accuracy train: 0.9980283975601196, val:0.9924556612968445
# LOSS train 0.0061223417868761345 valid 0.0
# Training vs Validation loss {'Training': 0.0061223417868761345, 'Validation': 0.0061223417868761345} 70
# Training vs validation loss {'Training': 0.9980283975601196, 'Validation': 0.9924556612968445} 70
# Epoch 70:
# Accuracy train: 0.9984391927719116, val:0.9766126275062561
# LOSS train 0.005997819602436272 valid 0.0
# Training vs Validation loss {'Training': 0.005997819602436272, 'Validation': 0.005997819602436272} 71
# Training vs validation loss {'Training': 0.9984391927719116, 'Validation': 0.9766126275062561} 71
# Epoch 71:
# Accuracy train: 0.9985213279724121, val:0.9888721108436584
# LOSS train 0.006023929406575701 valid 0.0
# Training vs Validation loss {'Training': 0.006023929406575701, 'Validation': 0.006023929406575701} 72
# Training vs validation loss {'Training': 0.9985213279724121, 'Validation': 0.9888721108436584} 72
# Epoch 72:
# Accuracy train: 0.9988499283790588, val:0.9913240075111389
# LOSS train 0.004134028617876013 valid 0.0
# Training vs Validation loss {'Training': 0.004134028617876013, 'Validation': 0.004134028617876013} 73
# Training vs validation loss {'Training': 0.9988499283790588, 'Validation': 0.9913240075111389} 73
# Epoch 73:
# Accuracy train: 0.9976998567581177, val:0.9898151755332947
# LOSS train 0.006930433030790899 valid 0.0
# Training vs Validation loss {'Training': 0.006930433030790899, 'Validation': 0.006930433030790899} 74
# Training vs validation loss {'Training': 0.9976998567581177, 'Validation': 0.9898151755332947} 74
# Epoch 74:
# Accuracy train: 0.9986034631729126, val:0.9917012453079224
# LOSS train 0.004823817249117573 valid 0.0
# Training vs Validation loss {'Training': 0.004823817249117573, 'Validation': 0.004823817249117573} 75
# Training vs validation loss {'Training': 0.9986034631729126, 'Validation': 0.9917012453079224} 75
# Epoch 75:
# Accuracy train: 0.9984391927719116, val:0.980007529258728
# LOSS train 0.005757115545589059 valid 0.0
# Training vs Validation loss {'Training': 0.005757115545589059, 'Validation': 0.005757115545589059} 76
# Training vs validation loss {'Training': 0.9984391927719116, 'Validation': 0.980007529258728} 76
# Epoch 76:
# Accuracy train: 0.9985213279724121, val:0.9766126275062561
# LOSS train 0.004241597947850201 valid 0.0
# Training vs Validation loss {'Training': 0.004241597947850201, 'Validation': 0.004241597947850201} 77
# Training vs validation loss {'Training': 0.9985213279724121, 'Validation': 0.9766126275062561} 77
# Epoch 77:
# Accuracy train: 0.9982748627662659, val:0.9786872863769531
# LOSS train 0.004571636236334214 valid 0.0
# Training vs Validation loss {'Training': 0.004571636236334214, 'Validation': 0.004571636236334214} 78
# Training vs validation loss {'Training': 0.9982748627662659, 'Validation': 0.9786872863769531} 78
# Epoch 78:
# Accuracy train: 0.9979462623596191, val:0.9741606712341309
# LOSS train 0.005453304794667422 valid 0.0
# Training vs Validation loss {'Training': 0.005453304794667422, 'Validation': 0.005453304794667422} 79
# Training vs validation loss {'Training': 0.9979462623596191, 'Validation': 0.9741606712341309} 79
# Epoch 79:
# Accuracy train: 0.9986034631729126, val:0.9768012166023254
# LOSS train 0.003879561861848191 valid 0.0
# Training vs Validation loss {'Training': 0.003879561861848191, 'Validation': 0.003879561861848191} 80
# Training vs validation loss {'Training': 0.9986034631729126, 'Validation': 0.9768012166023254} 80
# Epoch 80:
# Accuracy train: 0.9981105923652649, val:0.9954733848571777
# LOSS train 0.006074025706215304 valid 0.0
# Training vs Validation loss {'Training': 0.006074025706215304, 'Validation': 0.006074025706215304} 81
# Training vs validation loss {'Training': 0.9981105923652649, 'Validation': 0.9954733848571777} 81
# Epoch 81:
# Accuracy train: 0.9984391927719116, val:0.986420214176178
# LOSS train 0.004219718326911832 valid 0.0
# Training vs Validation loss {'Training': 0.004219718326911832, 'Validation': 0.004219718326911832} 82
# Training vs validation loss {'Training': 0.9984391927719116, 'Validation': 0.986420214176178} 82
# Epoch 82:
# Accuracy train: 0.9989320635795593, val:0.9873632788658142
# LOSS train 0.0030412328791502518 valid 0.0
# Training vs Validation loss {'Training': 0.0030412328791502518, 'Validation': 0.0030412328791502518} 83
# Training vs validation loss {'Training': 0.9989320635795593, 'Validation': 0.9873632788658142} 83
# Epoch 83:
# Accuracy train: 0.9983569979667664, val:0.9896265268325806
# LOSS train 0.00783247267537185 valid 0.0
# Training vs Validation loss {'Training': 0.00783247267537185, 'Validation': 0.00783247267537185} 84
# Training vs validation loss {'Training': 0.9983569979667664, 'Validation': 0.9896265268325806} 84
# Epoch 84:
# Accuracy train: 0.9989320635795593, val:0.9928328990936279
# LOSS train 0.004786835072745742 valid 0.0
# Training vs Validation loss {'Training': 0.004786835072745742, 'Validation': 0.004786835072745742} 85
# Training vs validation loss {'Training': 0.9989320635795593, 'Validation': 0.9928328990936279} 85
# Epoch 85:
# Accuracy train: 0.9981105923652649, val:0.9775556325912476
# LOSS train 0.0040332851194571796 valid 0.0
# Training vs Validation loss {'Training': 0.0040332851194571796, 'Validation': 0.0040332851194571796} 86
# Training vs validation loss {'Training': 0.9981105923652649, 'Validation': 0.9775556325912476} 86
# Epoch 86:
# Accuracy train: 0.9986034631729126, val:0.9860429763793945
# LOSS train 0.0036095134163598476 valid 0.0
# Training vs Validation loss {'Training': 0.0036095134163598476, 'Validation': 0.0036095134163598476} 87
# Training vs validation loss {'Training': 0.9986034631729126, 'Validation': 0.9860429763793945} 87
# Epoch 87:
# Accuracy train: 0.9986034631729126, val:0.9786872863769531
# LOSS train 0.004702916956161304 valid 0.0
# Training vs Validation loss {'Training': 0.004702916956161304, 'Validation': 0.004702916956161304} 88
# Training vs validation loss {'Training': 0.9986034631729126, 'Validation': 0.9786872863769531} 88
# Epoch 88:
# Accuracy train: 0.9981105923652649, val:0.9845341444015503
# LOSS train 0.003994592746794921 valid 0.0
# Training vs Validation loss {'Training': 0.003994592746794921, 'Validation': 0.003994592746794921} 89
# Training vs validation loss {'Training': 0.9981105923652649, 'Validation': 0.9845341444015503} 89
# Epoch 89:
# Accuracy train: 0.9985213279724121, val:0.9652960896492004
# LOSS train 0.0070034262654545395 valid 0.0
# Training vs Validation loss {'Training': 0.0070034262654545395, 'Validation': 0.0070034262654545395} 90
# Training vs validation loss {'Training': 0.9985213279724121, 'Validation': 0.9652960896492004} 90
# Epoch 90:
# Accuracy train: 0.9988499283790588, val:0.9771783947944641
# LOSS train 0.004827952615906687 valid 0.0
# Training vs Validation loss {'Training': 0.004827952615906687, 'Validation': 0.004827952615906687} 91
# Training vs validation loss {'Training': 0.9988499283790588, 'Validation': 0.9771783947944641} 91
# Epoch 91:
# Accuracy train: 0.9988499283790588, val:0.9790645241737366
# LOSS train 0.007383051354005547 valid 0.0
# Training vs Validation loss {'Training': 0.007383051354005547, 'Validation': 0.007383051354005547} 92
# Training vs validation loss {'Training': 0.9988499283790588, 'Validation': 0.9790645241737366} 92
# Epoch 92:
# Accuracy train: 0.9983569979667664, val:0.9654847383499146
# LOSS train 0.004875445867404215 valid 0.0
# Training vs Validation loss {'Training': 0.004875445867404215, 'Validation': 0.004875445867404215} 93
# Training vs validation loss {'Training': 0.9983569979667664, 'Validation': 0.9654847383499146} 93
# Epoch 93:
# Accuracy train: 0.9981927275657654, val:0.9850999712944031
# LOSS train 0.004878614093069596 valid 0.0
# Training vs Validation loss {'Training': 0.004878614093069596, 'Validation': 0.004878614093069596} 94
# Training vs validation loss {'Training': 0.9981927275657654, 'Validation': 0.9850999712944031} 94
# Epoch 94:
# Accuracy train: 0.9990141987800598, val:0.981516420841217
# LOSS train 0.00640231346139488 valid 0.0
# Training vs Validation loss {'Training': 0.00640231346139488, 'Validation': 0.00640231346139488} 95
# Training vs validation loss {'Training': 0.9990141987800598, 'Validation': 0.981516420841217} 95
# Epoch 95:
# Accuracy train: 0.9986034631729126, val:0.9849113821983337
# LOSS train 0.004381182858150438 valid 0.0
# Training vs Validation loss {'Training': 0.004381182858150438, 'Validation': 0.004381182858150438} 96
# Training vs validation loss {'Training': 0.9986034631729126, 'Validation': 0.9849113821983337} 96
# Epoch 96:
# Accuracy train: 0.9988499283790588, val:0.9613353610038757
# LOSS train 0.00362624089801508 valid 0.0
# Training vs Validation loss {'Training': 0.00362624089801508, 'Validation': 0.00362624089801508} 97
# Training vs validation loss {'Training': 0.9988499283790588, 'Validation': 0.9613353610038757} 97
# Epoch 97:
# Accuracy train: 0.9983569979667664, val:0.9952847957611084
# LOSS train 0.0058586321488770295 valid 0.0
# Training vs Validation loss {'Training': 0.0058586321488770295, 'Validation': 0.0058586321488770295} 98
# Training vs validation loss {'Training': 0.9983569979667664, 'Validation': 0.9952847957611084} 98
# Epoch 98:
# Accuracy train: 0.9986034631729126, val:0.9839683175086975
# LOSS train 0.003950149811266252 valid 0.0
# Training vs Validation loss {'Training': 0.003950149811266252, 'Validation': 0.003950149811266252} 99
# Training vs validation loss {'Training': 0.9986034631729126, 'Validation': 0.9839683175086975} 99
# Epoch 99:
# Accuracy train: 0.9990141987800598, val:0.9837797284126282
# LOSS train 0.0034174226093273623 valid 0.0
# Training vs Validation loss {'Training': 0.0034174226093273623, 'Validation': 0.0034174226093273623} 100
# Training vs validation loss {'Training': 0.9990141987800598, 'Validation': 0.9837797284126282} 100
# Epoch 100:
# Accuracy train: 0.9987677931785583, val:0.9896265268325806
# LOSS train 0.005523374745008827 valid 0.0
# Training vs Validation loss {'Training': 0.005523374745008827, 'Validation': 0.005523374745008827} 101
# Training vs validation loss {'Training': 0.9987677931785583, 'Validation': 0.9896265268325806} 101
# Epoch 101:
# Accuracy train: 0.9986855983734131, val:0.9917012453079224
# LOSS train 0.005052487464990149 valid 0.0
# Training vs Validation loss {'Training': 0.005052487464990149, 'Validation': 0.005052487464990149} 102
# Training vs validation loss {'Training': 0.9986855983734131, 'Validation': 0.9917012453079224} 102
# Epoch 102:
# Accuracy train: 0.9982748627662659, val:0.9869860410690308
# LOSS train 0.005308835366856439 valid 0.0
# Training vs Validation loss {'Training': 0.005308835366856439, 'Validation': 0.005308835366856439} 103
# Training vs validation loss {'Training': 0.9982748627662659, 'Validation': 0.9869860410690308} 103
# Epoch 103:
# Accuracy train: 0.9988499283790588, val:0.9809505939483643
# LOSS train 0.005559003862994867 valid 0.0
# Training vs Validation loss {'Training': 0.005559003862994867, 'Validation': 0.005559003862994867} 104
# Training vs validation loss {'Training': 0.9988499283790588, 'Validation': 0.9809505939483643} 104
# Epoch 104:
# Accuracy train: 0.9986034631729126, val:0.9717087745666504
# LOSS train 0.0034946515796282006 valid 0.0
# Training vs Validation loss {'Training': 0.0034946515796282006, 'Validation': 0.0034946515796282006} 105
# Training vs validation loss {'Training': 0.9986034631729126, 'Validation': 0.9717087745666504} 105
# Epoch 105:
# Accuracy train: 0.9983569979667664, val:0.9598264694213867
# LOSS train 0.0031345607382478723 valid 0.0
# Training vs Validation loss {'Training': 0.0031345607382478723, 'Validation': 0.0031345607382478723} 106
# Training vs validation loss {'Training': 0.9983569979667664, 'Validation': 0.9598264694213867} 106
# Epoch 106:
# Accuracy train: 0.9989320635795593, val:0.9898151755332947
# LOSS train 0.0025491225182354875 valid 0.0
# Training vs Validation loss {'Training': 0.0025491225182354875, 'Validation': 0.0025491225182354875} 107
# Training vs validation loss {'Training': 0.9989320635795593, 'Validation': 0.9898151755332947} 107
# Epoch 107:
# Accuracy train: 0.9987677931785583, val:0.9852885603904724
# LOSS train 0.003748481529944841 valid 0.0
# Training vs Validation loss {'Training': 0.003748481529944841, 'Validation': 0.003748481529944841} 108
# Training vs validation loss {'Training': 0.9987677931785583, 'Validation': 0.9852885603904724} 108
# Epoch 108:
# Accuracy train: 0.9988499283790588, val:0.9837797284126282
# LOSS train 0.003363301796013963 valid 0.0
# Training vs Validation loss {'Training': 0.003363301796013963, 'Validation': 0.003363301796013963} 109
# Training vs validation loss {'Training': 0.9988499283790588, 'Validation': 0.9837797284126282} 109
# Epoch 109:
# Accuracy train: 0.999260663986206, val:0.9849113821983337
# LOSS train 0.0034855905438617206 valid 0.0
# Training vs Validation loss {'Training': 0.0034855905438617206, 'Validation': 0.0034855905438617206} 110
# Training vs validation loss {'Training': 0.999260663986206, 'Validation': 0.9849113821983337} 110
# Epoch 110:
# Accuracy train: 0.9990963339805603, val:0.9711429476737976
# LOSS train 0.0030954875139542625 valid 0.0
# Training vs Validation loss {'Training': 0.0030954875139542625, 'Validation': 0.0030954875139542625} 111
# Training vs validation loss {'Training': 0.9990963339805603, 'Validation': 0.9711429476737976} 111
# Epoch 111:
# Accuracy train: 0.9983569979667664, val:0.9884949326515198
# LOSS train 0.005176154314995892 valid 0.0
# Training vs Validation loss {'Training': 0.005176154314995892, 'Validation': 0.005176154314995892} 112
# Training vs validation loss {'Training': 0.9983569979667664, 'Validation': 0.9884949326515198} 112
# Epoch 112:
# Accuracy train: 0.9990141987800598, val:0.9956620335578918
# LOSS train 0.004482585808274972 valid 0.0
# Training vs Validation loss {'Training': 0.004482585808274972, 'Validation': 0.004482585808274972} 113
# Training vs validation loss {'Training': 0.9990141987800598, 'Validation': 0.9956620335578918} 113
# Epoch 113:
# Accuracy train: 0.9988499283790588, val:0.9903810024261475
# LOSS train 0.004701787468373378 valid 0.0
# Training vs Validation loss {'Training': 0.004701787468373378, 'Validation': 0.004701787468373378} 114
# Training vs validation loss {'Training': 0.9988499283790588, 'Validation': 0.9903810024261475} 114
# Epoch 114:
# Accuracy train: 0.9983569979667664, val:0.9905695915222168
# LOSS train 0.004827682842500977 valid 0.0
# Training vs Validation loss {'Training': 0.004827682842500977, 'Validation': 0.004827682842500977} 115
# Training vs validation loss {'Training': 0.9983569979667664, 'Validation': 0.9905695915222168} 115
# Epoch 115:
# Accuracy train: 0.9989320635795593, val:0.99358731508255
# LOSS train 0.0042796773451224766 valid 0.0
# Training vs Validation loss {'Training': 0.0042796773451224766, 'Validation': 0.0042796773451224766} 116
# Training vs validation loss {'Training': 0.9989320635795593, 'Validation': 0.99358731508255} 116
# Epoch 116:
# Accuracy train: 0.9985213279724121, val:0.9896265268325806
# LOSS train 0.00333327224222662 valid 0.0
# Training vs Validation loss {'Training': 0.00333327224222662, 'Validation': 0.00333327224222662} 117
# Training vs validation loss {'Training': 0.9985213279724121, 'Validation': 0.9896265268325806} 117
# Epoch 117:
# Accuracy train: 0.9985213279724121, val:0.9837797284126282
# LOSS train 0.005632905164693946 valid 0.0
# Training vs Validation loss {'Training': 0.005632905164693946, 'Validation': 0.005632905164693946} 118
# Training vs validation loss {'Training': 0.9985213279724121, 'Validation': 0.9837797284126282} 118
# Epoch 118:
# Accuracy train: 0.9986034631729126, val:0.9739720821380615
# LOSS train 0.004939203168900368 valid 0.0
# Training vs Validation loss {'Training': 0.004939203168900368, 'Validation': 0.004939203168900368} 119
# Training vs validation loss {'Training': 0.9986034631729126, 'Validation': 0.9739720821380615} 119
# Epoch 119:
# Accuracy train: 0.9988499283790588, val:0.9622783660888672
# LOSS train 0.00290082185244953 valid 0.0
# Training vs Validation loss {'Training': 0.00290082185244953, 'Validation': 0.00290082185244953} 120
# Training vs validation loss {'Training': 0.9988499283790588, 'Validation': 0.9622783660888672} 120
# Epoch 120:
# Accuracy train: 0.9989320635795593, val:0.9888721108436584
# LOSS train 0.0025488123191316635 valid 0.0
# Training vs Validation loss {'Training': 0.0025488123191316635, 'Validation': 0.0025488123191316635} 121
# Training vs validation loss {'Training': 0.9989320635795593, 'Validation': 0.9888721108436584} 121
# Epoch 121:
# Accuracy train: 0.9988499283790588, val:0.9788758754730225
# LOSS train 0.002875300123775272 valid 0.0
# Training vs Validation loss {'Training': 0.002875300123775272, 'Validation': 0.002875300123775272} 122
# Training vs validation loss {'Training': 0.9988499283790588, 'Validation': 0.9788758754730225} 122
# Epoch 122:
# Accuracy train: 0.9986855983734131, val:0.9817050099372864
# LOSS train 0.005876465931977081 valid 0.0
# Training vs Validation loss {'Training': 0.005876465931977081, 'Validation': 0.005876465931977081} 123
# Training vs validation loss {'Training': 0.9986855983734131, 'Validation': 0.9817050099372864} 123
# Epoch 123:
# Accuracy train: 0.9986855983734131, val:0.9866088032722473
# LOSS train 0.004439629137490629 valid 0.0
# Training vs Validation loss {'Training': 0.004439629137490629, 'Validation': 0.004439629137490629} 124
# Training vs validation loss {'Training': 0.9986855983734131, 'Validation': 0.9866088032722473} 124
# Epoch 124:
# Accuracy train: 0.9990963339805603, val:0.9751037359237671
# LOSS train 0.0028574519642243093 valid 0.0
# Training vs Validation loss {'Training': 0.0028574519642243093, 'Validation': 0.0028574519642243093} 125
# Training vs validation loss {'Training': 0.9990963339805603, 'Validation': 0.9751037359237671} 125
# Epoch 125:
# Accuracy train: 0.9986034631729126, val:0.9907581806182861
# LOSS train 0.004169993114018392 valid 0.0
# Training vs Validation loss {'Training': 0.004169993114018392, 'Validation': 0.004169993114018392} 126
# Training vs validation loss {'Training': 0.9986034631729126, 'Validation': 0.9907581806182861} 126
# Epoch 126:
# Accuracy train: 0.9987677931785583, val:0.991512656211853
# LOSS train 0.0035580666245458538 valid 0.0
# Training vs Validation loss {'Training': 0.0035580666245458538, 'Validation': 0.0035580666245458538} 127
# Training vs validation loss {'Training': 0.9987677931785583, 'Validation': 0.991512656211853} 127
# Epoch 127:
# Accuracy train: 0.999260663986206, val:0.9901923537254333
# LOSS train 0.002437192526245584 valid 0.0
# Training vs Validation loss {'Training': 0.002437192526245584, 'Validation': 0.002437192526245584} 128
# Training vs validation loss {'Training': 0.999260663986206, 'Validation': 0.9901923537254333} 128
# Epoch 128:
# Accuracy train: 0.9989320635795593, val:0.9826480746269226
# LOSS train 0.0028299200714097636 valid 0.0
# Training vs Validation loss {'Training': 0.0028299200714097636, 'Validation': 0.0028299200714097636} 129
# Training vs validation loss {'Training': 0.9989320635795593, 'Validation': 0.9826480746269226} 129
# Epoch 129:
# Accuracy train: 0.9990141987800598, val:0.99358731508255
# LOSS train 0.0023455504561312912 valid 0.0
# Training vs Validation loss {'Training': 0.0023455504561312912, 'Validation': 0.0023455504561312912} 130
# Training vs validation loss {'Training': 0.9990141987800598, 'Validation': 0.99358731508255} 130
# Epoch 130:
# Accuracy train: 0.9989320635795593, val:0.9933987259864807
# LOSS train 0.00378439385487995 valid 0.0
# Training vs Validation loss {'Training': 0.00378439385487995, 'Validation': 0.00378439385487995} 131
# Training vs validation loss {'Training': 0.9989320635795593, 'Validation': 0.9933987259864807} 131
# Epoch 131:
# Accuracy train: 0.9986034631729126, val:0.9737834930419922
# LOSS train 0.0030929640689254124 valid 0.0
# Training vs Validation loss {'Training': 0.0030929640689254124, 'Validation': 0.0030929640689254124} 132
# Training vs validation loss {'Training': 0.9986034631729126, 'Validation': 0.9737834930419922} 132
# Epoch 132:
# Accuracy train: 0.9986855983734131, val:0.9926443099975586
# LOSS train 0.0034635855270405505 valid 0.0
# Training vs Validation loss {'Training': 0.0034635855270405505, 'Validation': 0.0034635855270405505} 133
# Training vs validation loss {'Training': 0.9986855983734131, 'Validation': 0.9926443099975586} 133
# Epoch 133:
# Accuracy train: 0.9987677931785583, val:0.9830252528190613
# LOSS train 0.0034533948094672843 valid 0.0
# Training vs Validation loss {'Training': 0.0034533948094672843, 'Validation': 0.0034533948094672843} 134
# Training vs validation loss {'Training': 0.9987677931785583, 'Validation': 0.9830252528190613} 134
# Epoch 134:
# Accuracy train: 0.9990963339805603, val:0.9941531419754028
# LOSS train 0.0028506176161912054 valid 0.0
# Training vs Validation loss {'Training': 0.0028506176161912054, 'Validation': 0.0028506176161912054} 135
# Training vs validation loss {'Training': 0.9990963339805603, 'Validation': 0.9941531419754028} 135
# Epoch 135:
# Accuracy train: 0.9995071291923523, val:0.9926443099975586
# LOSS train 0.0020562489359430497 valid 0.0
# Training vs Validation loss {'Training': 0.0020562489359430497, 'Validation': 0.0020562489359430497} 136
# Training vs validation loss {'Training': 0.9995071291923523, 'Validation': 0.9926443099975586} 136
# Epoch 136:
# Accuracy train: 0.999260663986206, val:0.9718974232673645
# LOSS train 0.00250120688766835 valid 0.0
# Training vs Validation loss {'Training': 0.00250120688766835, 'Validation': 0.00250120688766835} 137
# Training vs validation loss {'Training': 0.999260663986206, 'Validation': 0.9718974232673645} 137
# Epoch 137:
# Accuracy train: 0.9989320635795593, val:0.9820822477340698
# LOSS train 0.004840661338877025 valid 0.0
# Training vs Validation loss {'Training': 0.004840661338877025, 'Validation': 0.004840661338877025} 138
# Training vs validation loss {'Training': 0.9989320635795593, 'Validation': 0.9820822477340698} 138
# Epoch 138:
# Accuracy train: 0.9990141987800598, val:0.9786872863769531
# LOSS train 0.0033016211899119883 valid 0.0
# Training vs Validation loss {'Training': 0.0033016211899119883, 'Validation': 0.0033016211899119883} 139
# Training vs validation loss {'Training': 0.9990141987800598, 'Validation': 0.9786872863769531} 139
# Epoch 139:
# Accuracy train: 0.9993427991867065, val:0.9881176948547363
# LOSS train 0.0028701268628902217 valid 0.0
# Training vs Validation loss {'Training': 0.0028701268628902217, 'Validation': 0.0028701268628902217} 140
# Training vs validation loss {'Training': 0.9993427991867065, 'Validation': 0.9881176948547363} 140
# Epoch 140:
# Accuracy train: 0.999260663986206, val:0.9901923537254333
# LOSS train 0.0036677363572370923 valid 0.0
# Training vs Validation loss {'Training': 0.0036677363572370923, 'Validation': 0.0036677363572370923} 141
# Training vs validation loss {'Training': 0.999260663986206, 'Validation': 0.9901923537254333} 141
# Epoch 141:
# Accuracy train: 0.9990963339805603, val:0.9830252528190613
# LOSS train 0.002504982334409958 valid 0.0
# Training vs Validation loss {'Training': 0.002504982334409958, 'Validation': 0.002504982334409958} 142
# Training vs validation loss {'Training': 0.9990963339805603, 'Validation': 0.9830252528190613} 142
# Epoch 142:
# Accuracy train: 0.9988499283790588, val:0.9751037359237671
# LOSS train 0.0031040294314689867 valid 0.0
# Training vs Validation loss {'Training': 0.0031040294314689867, 'Validation': 0.0031040294314689867} 143
# Training vs validation loss {'Training': 0.9988499283790588, 'Validation': 0.9751037359237671} 143
# Epoch 143:
# Accuracy train: 0.999424934387207, val:0.9932101368904114
# LOSS train 0.0018386436659490095 valid 0.0
# Training vs Validation loss {'Training': 0.0018386436659490095, 'Validation': 0.0018386436659490095} 144
# Training vs validation loss {'Training': 0.999424934387207, 'Validation': 0.9932101368904114} 144
# Epoch 144:
# Accuracy train: 0.999260663986206, val:0.9849113821983337
# LOSS train 0.0035857569036346288 valid 0.0
# Training vs Validation loss {'Training': 0.0035857569036346288, 'Validation': 0.0035857569036346288} 145
# Training vs validation loss {'Training': 0.999260663986206, 'Validation': 0.9849113821983337} 145
# Epoch 145:
# Accuracy train: 0.9986034631729126, val:0.9747264981269836
# LOSS train 0.0037504881996116915 valid 0.0
# Training vs Validation loss {'Training': 0.0037504881996116915, 'Validation': 0.0037504881996116915} 146
# Training vs validation loss {'Training': 0.9986034631729126, 'Validation': 0.9747264981269836} 146
# Epoch 146:
# Accuracy train: 0.999424934387207, val:0.9862316250801086
# LOSS train 0.002790329909079209 valid 0.0
# Training vs Validation loss {'Training': 0.002790329909079209, 'Validation': 0.002790329909079209} 147
# Training vs validation loss {'Training': 0.999424934387207, 'Validation': 0.9862316250801086} 147
# Epoch 147:
# Accuracy train: 0.999835729598999, val:0.9850999712944031
# LOSS train 0.002391406928116352 valid 0.0
# Training vs Validation loss {'Training': 0.002391406928116352, 'Validation': 0.002391406928116352} 148
# Training vs validation loss {'Training': 0.999835729598999, 'Validation': 0.9850999712944031} 148
# Epoch 148:
# Accuracy train: 0.9993427991867065, val:0.9735948443412781
# LOSS train 0.0019304127958149244 valid 0.0
# Training vs Validation loss {'Training': 0.0019304127958149244, 'Validation': 0.0019304127958149244} 149
# Training vs validation loss {'Training': 0.9993427991867065, 'Validation': 0.9735948443412781} 149
# Epoch 149:
# Accuracy train: 0.999424934387207, val:0.9798189401626587
# LOSS train 0.0020201650437908173 valid 0.0
# Training vs Validation loss {'Training': 0.0020201650437908173, 'Validation': 0.0020201650437908173} 150
# Training vs validation loss {'Training': 0.999424934387207, 'Validation': 0.9798189401626587} 150
# Epoch 150:
# Accuracy train: 0.9995071291923523, val:0.9709543585777283
# LOSS train 0.0018515802183804407 valid 0.0
# Training vs Validation loss {'Training': 0.0018515802183804407, 'Validation': 0.0018515802183804407} 151
# Training vs validation loss {'Training': 0.9995071291923523, 'Validation': 0.9709543585777283} 151
# Epoch 151:
# Accuracy train: 0.9990141987800598, val:0.9956620335578918
# LOSS train 0.004234514769087926 valid 0.0
# Training vs Validation loss {'Training': 0.004234514769087926, 'Validation': 0.004234514769087926} 152
# Training vs validation loss {'Training': 0.9990141987800598, 'Validation': 0.9956620335578918} 152
# Epoch 152:
# Accuracy train: 0.9993427991867065, val:0.9818935990333557
# LOSS train 0.006178490235321273 valid 0.0
# Training vs Validation loss {'Training': 0.006178490235321273, 'Validation': 0.006178490235321273} 153
# Training vs validation loss {'Training': 0.9993427991867065, 'Validation': 0.9818935990333557} 153
# Epoch 153:
# Accuracy train: 0.9995071291923523, val:0.9958506226539612
# LOSS train 0.0016590255405596111 valid 0.0
# ...
# Training vs validation loss {'Training': 0.9990141987800598, 'Validation': 0.9883062839508057} 250
# Epoch 250:
# Accuracy train: 0.9993427991867065, val:0.9917012453079224
# LOSS train 0.0024916282264240905 valid 0.0
# Training vs Validation loss {'Training': 0.0024916282264240905, 'Validation': 0.0024916282264240905} 251
# Training vs validation loss {'Training': 0.9993427991867065, 'Validation': 0.9917012453079224} 251
# Epoch 251:
# Accuracy train: 0.9990141987800598, val:0.9903810024261475
# LOSS train 0.0034416160325303246 valid 0.0
# Training vs Validation loss {'Training': 0.0034416160325303246, 'Validation': 0.0034416160325303246} 252
# Training vs validation loss {'Training': 0.9990141987800598, 'Validation': 0.9903810024261475} 252
# Epoch 252:
# Accuracy train: 0.9997535347938538, val:0.9873632788658142
# LOSS train 0.001405741576690295 valid 0.0
# Training vs Validation loss {'Training': 0.001405741576690295, 'Validation': 0.001405741576690295} 253
# Training vs validation loss {'Training': 0.9997535347938538, 'Validation': 0.9873632788658142} 253
# Epoch 253:
# Accuracy train: 0.999835729598999, val:0.9871746301651001
# LOSS train 0.0006426323942037001 valid 0.0
# Training vs Validation loss {'Training': 0.0006426323942037001, 'Validation': 0.0006426323942037001} 254
# Training vs validation loss {'Training': 0.999835729598999, 'Validation': 0.9871746301651001} 254
# Epoch 254:
# Accuracy train: 0.999835729598999, val:0.9913240075111389
# LOSS train 0.0020711840950362087 valid 0.0
# Training vs Validation loss {'Training': 0.0020711840950362087, 'Validation': 0.0020711840950362087} 255
# Training vs validation loss {'Training': 0.999835729598999, 'Validation': 0.9913240075111389} 255
# Epoch 255:
# Accuracy train: 0.9990963339805603, val:0.996416449546814
# LOSS train 0.002846399423511647 valid 0.0
# Training vs Validation loss {'Training': 0.002846399423511647, 'Validation': 0.002846399423511647} 256
# Training vs validation loss {'Training': 0.9990963339805603, 'Validation': 0.996416449546814} 256
# Epoch 256:
# Accuracy train: 0.9995071291923523, val:0.9937759041786194
# LOSS train 0.0022950220767365636 valid 0.0
# Training vs Validation loss {'Training': 0.0022950220767365636, 'Validation': 0.0022950220767365636} 257
# Training vs validation loss {'Training': 0.9995071291923523, 'Validation': 0.9937759041786194} 257
# Epoch 257:
# Accuracy train: 0.9995071291923523, val:0.998491108417511
# LOSS train 0.0025711207260283456 valid 0.0
# Training vs Validation loss {'Training': 0.0025711207260283456, 'Validation': 0.0025711207260283456} 258
# Training vs validation loss {'Training': 0.9995071291923523, 'Validation': 0.998491108417511} 258
# Epoch 258:
# Accuracy train: 0.9995892643928528, val:0.9962278604507446
# LOSS train 0.002439474880826967 valid 0.0
# Training vs Validation loss {'Training': 0.002439474880826967, 'Validation': 0.002439474880826967} 259
# Training vs validation loss {'Training': 0.9995892643928528, 'Validation': 0.9962278604507446} 259
# Epoch 259:
# Accuracy train: 0.9990141987800598, val:0.9903810024261475
# LOSS train 0.004288694523327667 valid 0.0
# Training vs Validation loss {'Training': 0.004288694523327667, 'Validation': 0.004288694523327667} 260
# Training vs validation loss {'Training': 0.9990141987800598, 'Validation': 0.9903810024261475} 260
# Epoch 260:
# Accuracy train: 0.9995892643928528, val:0.996416449546814
# LOSS train 0.002402691351757494 valid 0.0
# Training vs Validation loss {'Training': 0.002402691351757494, 'Validation': 0.002402691351757494} 261
# Training vs validation loss {'Training': 0.9995892643928528, 'Validation': 0.996416449546814} 261
# Epoch 261:
# Accuracy train: 0.9995892643928528, val:0.9801961779594421
# LOSS train 0.003521928885440424 valid 0.0
# Training vs Validation loss {'Training': 0.003521928885440424, 'Validation': 0.003521928885440424} 262
# Training vs validation loss {'Training': 0.9995892643928528, 'Validation': 0.9801961779594421} 262
# Epoch 262:
# Accuracy train: 0.9990963339805603, val:0.9896265268325806
# LOSS train 0.002800460823563131 valid 0.0
# Training vs Validation loss {'Training': 0.002800460823563131, 'Validation': 0.002800460823563131} 263
# Training vs validation loss {'Training': 0.9990963339805603, 'Validation': 0.9896265268325806} 263
# Epoch 263:
# Accuracy train: 0.9999178647994995, val:0.9975481033325195
# LOSS train 0.0005564064044452598 valid 0.0
# Training vs Validation loss {'Training': 0.0005564064044452598, 'Validation': 0.0005564064044452598} 264
# Training vs validation loss {'Training': 0.9999178647994995, 'Validation': 0.9975481033325195} 264
# Epoch 264:
# Accuracy train: 0.9995071291923523, val:0.9960392117500305
# LOSS train 0.0026268030276941526 valid 0.0
# Training vs Validation loss {'Training': 0.0026268030276941526, 'Validation': 0.0026268030276941526} 265
# Training vs validation loss {'Training': 0.9995071291923523, 'Validation': 0.9960392117500305} 265
# Epoch 265:
# Accuracy train: 0.9995892643928528, val:0.9839683175086975
# LOSS train 0.0025326053124775385 valid 0.0
# Training vs Validation loss {'Training': 0.0025326053124775385, 'Validation': 0.0025326053124775385} 266
# Training vs validation loss {'Training': 0.9995892643928528, 'Validation': 0.9839683175086975} 266
# Epoch 266:
# Accuracy train: 0.9997535347938538, val:0.9930214881896973
# LOSS train 0.0016652535617453343 valid 0.0
# Training vs Validation loss {'Training': 0.0016652535617453343, 'Validation': 0.0016652535617453343} 267
# Training vs validation loss {'Training': 0.9997535347938538, 'Validation': 0.9930214881896973} 267
# Epoch 267:
# Accuracy train: 0.9995071291923523, val:0.9905695915222168
# LOSS train 0.001367668026034028 valid 0.0
# Training vs Validation loss {'Training': 0.001367668026034028, 'Validation': 0.001367668026034028} 268
# Training vs validation loss {'Training': 0.9995071291923523, 'Validation': 0.9905695915222168} 268
# Epoch 268:
# Accuracy train: 0.9995071291923523, val:0.9947189688682556
# LOSS train 0.002033196171315241 valid 0.0
# Training vs Validation loss {'Training': 0.002033196171315241, 'Validation': 0.002033196171315241} 269
# Training vs validation loss {'Training': 0.9995071291923523, 'Validation': 0.9947189688682556} 269
# Epoch 269:
# Accuracy train: 0.9989320635795593, val:0.9917012453079224
# LOSS train 0.0036778957197618136 valid 0.0
# Training vs Validation loss {'Training': 0.0036778957197618136, 'Validation': 0.0036778957197618136} 270
# Training vs validation loss {'Training': 0.9989320635795593, 'Validation': 0.9917012453079224} 270
# Epoch 270:
# Accuracy train: 0.999424934387207, val:0.9901923537254333
# LOSS train 0.002852034820266768 valid 0.0
# Training vs Validation loss {'Training': 0.002852034820266768, 'Validation': 0.002852034820266768} 271
# Training vs validation loss {'Training': 0.999424934387207, 'Validation': 0.9901923537254333} 271
# Epoch 271:
# Accuracy train: 0.9996713995933533, val:0.994907557964325
# LOSS train 0.0011647644656987092 valid 0.0
# Training vs Validation loss {'Training': 0.0011647644656987092, 'Validation': 0.0011647644656987092} 272
# Training vs validation loss {'Training': 0.9996713995933533, 'Validation': 0.994907557964325} 272
# Epoch 272:
# Accuracy train: 0.9996713995933533, val:0.9917012453079224
# LOSS train 0.0009648998265825124 valid 0.0
# Training vs Validation loss {'Training': 0.0009648998265825124, 'Validation': 0.0009648998265825124} 273
# Training vs validation loss {'Training': 0.9996713995933533, 'Validation': 0.9917012453079224} 273
# Epoch 273:
# Accuracy train: 0.999424934387207, val:0.9566201567649841
# LOSS train 0.0016006482749348163 valid 0.0
# Training vs Validation loss {'Training': 0.0016006482749348163, 'Validation': 0.0016006482749348163} 274
# Training vs validation loss {'Training': 0.999424934387207, 'Validation': 0.9566201567649841} 274
# Epoch 274:
# Accuracy train: 0.999424934387207, val:0.99358731508255
# LOSS train 0.0025459820833574356 valid 0.0
# Training vs Validation loss {'Training': 0.0025459820833574356, 'Validation': 0.0025459820833574356} 275
# Training vs validation loss {'Training': 0.999424934387207, 'Validation': 0.99358731508255} 275
# Epoch 275:
# Accuracy train: 0.9995892643928528, val:0.9901923537254333
# LOSS train 0.002218355216130016 valid 0.0
# Training vs Validation loss {'Training': 0.002218355216130016, 'Validation': 0.002218355216130016} 276
# Training vs validation loss {'Training': 0.9995892643928528, 'Validation': 0.9901923537254333} 276
# Epoch 276:
# Accuracy train: 0.9993427991867065, val:0.9871746301651001
# LOSS train 0.00159754548318153 valid 0.0
# Training vs Validation loss {'Training': 0.00159754548318153, 'Validation': 0.00159754548318153} 277
# Training vs validation loss {'Training': 0.9993427991867065, 'Validation': 0.9871746301651001} 277
# Epoch 277:
# Accuracy train: 0.999835729598999, val:0.9894379377365112
# LOSS train 0.0009053670709920364 valid 0.0
# Training vs Validation loss {'Training': 0.0009053670709920364, 'Validation': 0.0009053670709920364} 278
# Training vs validation loss {'Training': 0.999835729598999, 'Validation': 0.9894379377365112} 278
# Epoch 278:
# Accuracy train: 0.9993427991867065, val:0.998491108417511
# LOSS train 0.0024519234026034002 valid 0.0
# Training vs Validation loss {'Training': 0.0024519234026034002, 'Validation': 0.0024519234026034002} 279
# Training vs validation loss {'Training': 0.9993427991867065, 'Validation': 0.998491108417511} 279
# Epoch 279:
# Accuracy train: 0.999424934387207, val:0.9826480746269226
# LOSS train 0.0021449726842623583 valid 0.0
# Training vs Validation loss {'Training': 0.0021449726842623583, 'Validation': 0.0021449726842623583} 280
# Training vs validation loss {'Training': 0.999424934387207, 'Validation': 0.9826480746269226} 280
# Epoch 280:
# Accuracy train: 0.999835729598999, val:0.9958506226539612
# LOSS train 0.0011462778045322572 valid 0.0
# Training vs Validation loss {'Training': 0.0011462778045322572, 'Validation': 0.0011462778045322572} 281
# Training vs validation loss {'Training': 0.999835729598999, 'Validation': 0.9958506226539612} 281
# Epoch 281:
# Accuracy train: 0.9996713995933533, val:0.9943417310714722
# LOSS train 0.001551018386294805 valid 0.0
# Training vs Validation loss {'Training': 0.001551018386294805, 'Validation': 0.001551018386294805} 282
# Training vs validation loss {'Training': 0.9996713995933533, 'Validation': 0.9943417310714722} 282
# Epoch 282:
# Accuracy train: 0.9997535347938538, val:0.974349319934845
# LOSS train 0.0006343843343064576 valid 0.0
# Training vs Validation loss {'Training': 0.0006343843343064576, 'Validation': 0.0006343843343064576} 283
# Training vs validation loss {'Training': 0.9997535347938538, 'Validation': 0.974349319934845} 283
# Epoch 283:
# Accuracy train: 0.9991785287857056, val:0.9950962066650391
# LOSS train 0.003924714021214605 valid 0.0
# Training vs Validation loss {'Training': 0.003924714021214605, 'Validation': 0.003924714021214605} 284
# Training vs validation loss {'Training': 0.9991785287857056, 'Validation': 0.9950962066650391} 284
# Epoch 284:
# Accuracy train: 0.9988499283790588, val:0.9898151755332947
# LOSS train 0.0025717021267166774 valid 0.0
# Training vs Validation loss {'Training': 0.0025717021267166774, 'Validation': 0.0025717021267166774} 285
# Training vs validation loss {'Training': 0.9988499283790588, 'Validation': 0.9898151755332947} 285
# Epoch 285:
# Accuracy train: 0.9995071291923523, val:0.9979252815246582
# LOSS train 0.0011427980245620492 valid 0.0
# Training vs Validation loss {'Training': 0.0011427980245620492, 'Validation': 0.0011427980245620492} 286
# Training vs validation loss {'Training': 0.9995071291923523, 'Validation': 0.9979252815246582} 286
# Epoch 286:
# Accuracy train: 0.9990963339805603, val:0.9852885603904724
# LOSS train 0.004416942823006076 valid 0.0
# Training vs Validation loss {'Training': 0.004416942823006076, 'Validation': 0.004416942823006076} 287
# Training vs validation loss {'Training': 0.9990963339805603, 'Validation': 0.9852885603904724} 287
# Epoch 287:
# Accuracy train: 0.9995892643928528, val:0.9937759041786194
# LOSS train 0.0018924174034592553 valid 0.0
# Training vs Validation loss {'Training': 0.0018924174034592553, 'Validation': 0.0018924174034592553} 288
# Training vs validation loss {'Training': 0.9995892643928528, 'Validation': 0.9937759041786194} 288
# Epoch 288:
# Accuracy train: 0.9996713995933533, val:0.9886835217475891
# LOSS train 0.0005904958248885284 valid 0.0
# Training vs Validation loss {'Training': 0.0005904958248885284, 'Validation': 0.0005904958248885284} 289
# Training vs validation loss {'Training': 0.9996713995933533, 'Validation': 0.9886835217475891} 289
# Epoch 289:
# Accuracy train: 0.9995892643928528, val:0.9943417310714722
# LOSS train 0.0012442916080825236 valid 0.0
# Training vs Validation loss {'Training': 0.0012442916080825236, 'Validation': 0.0012442916080825236} 290
# Training vs validation loss {'Training': 0.9995892643928528, 'Validation': 0.9943417310714722} 290
# Epoch 290:
# Accuracy train: 0.9997535347938538, val:0.9977366924285889
# LOSS train 0.0014541313424227477 valid 0.0
# Training vs Validation loss {'Training': 0.0014541313424227477, 'Validation': 0.0014541313424227477} 291
# Training vs validation loss {'Training': 0.9997535347938538, 'Validation': 0.9977366924285889} 291
# Epoch 291:
# Accuracy train: 0.9996713995933533, val:0.9856657981872559
# LOSS train 0.0021192651517365096 valid 0.0
# Training vs Validation loss {'Training': 0.0021192651517365096, 'Validation': 0.0021192651517365096} 292
# Training vs validation loss {'Training': 0.9996713995933533, 'Validation': 0.9856657981872559} 292
# Epoch 292:
# Accuracy train: 0.9996713995933533, val:0.9952847957611084
# LOSS train 0.0008966373193706 valid 0.0
# Training vs Validation loss {'Training': 0.0008966373193706, 'Validation': 0.0008966373193706} 293
# Training vs validation loss {'Training': 0.9996713995933533, 'Validation': 0.9952847957611084} 293
# Epoch 293:
# Accuracy train: 0.9995892643928528, val:0.9945303797721863
# LOSS train 0.001196764542982423 valid 0.0
# Training vs Validation loss {'Training': 0.001196764542982423, 'Validation': 0.001196764542982423} 294
# Training vs validation loss {'Training': 0.9995892643928528, 'Validation': 0.9945303797721863} 294
# Epoch 294:
# Accuracy train: 0.9995892643928528, val:0.9917012453079224
# LOSS train 0.0014791722465941348 valid 0.0
# Training vs Validation loss {'Training': 0.0014791722465941348, 'Validation': 0.0014791722465941348} 295
# Training vs validation loss {'Training': 0.9995892643928528, 'Validation': 0.9917012453079224} 295
# Epoch 295:
# Accuracy train: 0.9993427991867065, val:0.9781214594841003
# LOSS train 0.004915501344983393 valid 0.0
# Training vs Validation loss {'Training': 0.004915501344983393, 'Validation': 0.004915501344983393} 296
# Training vs validation loss {'Training': 0.9993427991867065, 'Validation': 0.9781214594841003} 296
# Epoch 296:
# Accuracy train: 0.9995892643928528, val:0.9971708655357361
# LOSS train 0.0012034286452453403 valid 0.0
# Training vs Validation loss {'Training': 0.0012034286452453403, 'Validation': 0.0012034286452453403} 297
# Training vs validation loss {'Training': 0.9995892643928528, 'Validation': 0.9971708655357361} 297
# Epoch 297:
# Accuracy train: 0.9996713995933533, val:0.9952847957611084
# LOSS train 0.0011794272486150752 valid 0.0
# Training vs Validation loss {'Training': 0.0011794272486150752, 'Validation': 0.0011794272486150752} 298
# Training vs validation loss {'Training': 0.9996713995933533, 'Validation': 0.9952847957611084} 298
# Epoch 298:
# Accuracy train: 0.9996713995933533, val:0.9892493486404419
# LOSS train 0.0005819224957692431 valid 0.0
# Training vs Validation loss {'Training': 0.0005819224957692431, 'Validation': 0.0005819224957692431} 299
# Training vs validation loss {'Training': 0.9996713995933533, 'Validation': 0.9892493486404419} 299
# Epoch 299:
# Accuracy train: 0.999424934387207, val:0.9909468293190002
# LOSS train 0.004194782272073591 valid 0.0
# Training vs Validation loss {'Training': 0.004194782272073591, 'Validation': 0.004194782272073591} 300
# Training vs validation loss {'Training': 0.999424934387207, 'Validation': 0.9909468293190002} 300
# tensor(0.9909)

# %%
list_label = label_dict_from_config_file("/content/drive/MyDrive/AIO_2024/Module_5/Week_5/hand_gesture.yaml")
DATA_FOLDER_PATH="/content/drive/MyDrive/AIO_2024/Module_5/Week_5/data"

testset = CustomImageDataset(os.path.join(DATA_FOLDER_PATH,"landmark_test.csv"))
test_loader = torch.utils.data.DataLoader(testset, batch_size=20, shuffle=False)

network = NeuralNetwork()
network.load_state_dict(torch.load(best_model_path, weights_only=False))

network.eval()
acc_test = Accuracy(num_classes=len(list_label), task='MULTICLASS')
for i, test_data in enumerate(test_loader):
    test_input, test_label = test_data
    preds = network(test_input)
    acc_test.update(preds, test_label)

print(network.__class__.__name__)
print(f"Accuracy of model:{acc_test.compute().item()}")
print("========================================================================")
# Out:
# NeuralNetwork
# Accuracy of model:0.9901162981987
# ========================================================================
